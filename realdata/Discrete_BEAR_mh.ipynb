# %%
import os
import copy
import random
import gym
import pickle

import numpy as np
import pandas as pd
import tensorflow as tf
tf.keras.backend.set_floatx('float32')

from itertools import permutations
from sklearn.model_selection import KFold, GridSearchCV

from multiprocessing import set_start_method
import multiprocessing as mp

path = os.path.abspath('..')
if path not in sys.path:
    sys.path.append(path)

from peal.agents.default_config import DEFAULT_CONFIG as config
# from peal.agents.dqn import DQNAgent
# from peal.agents.qr_dqn import QuantileAgent
# from peal.agents.multi_head_dqn import MultiHeadDQNAgent
# from peal.agents.discrete_bcq import DiscreteBCQAgent
from peal.agents.kl_control import KLAgent
from peal.algos.kfold import CVS, KFoldCV
from peal.algos.advantage_learner import AdvantageLearner
from peal.algos.behavior_cloning import BehaviorCloning
from peal.algos.density_ratio import VisitationRatioModel
from peal.algos.fqe import FQE

def one_step(seed):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    path = './data/mh/kl/trajs_mh.pkl'
    nfolds = 5
    n_splits = 5
    ckpts = (np.arange(10) + 1)*1000
    
    num_actions = 5
    # configures
    config['online'] = False
    config['lr'] = 5e-4
    config['decay_steps'] = 50000
    config['max_training_steps'] = 10000
    config['training_steps_to_checkpoint'] = 1000
    config['training_steps_to_eval'] = 100000
    config['hiddens'] = [64,64]
    config['constraint_hyperparm'] = 0.1

    index = pd.MultiIndex.from_product([np.arange(nfolds), ckpts])
    columns = ['dqn',  'peal']

    rets = pd.DataFrame(index=index, columns=columns)

    print('-'*20, 'start', '-'*20)
    cvs = CVS(path, n_splits=nfolds, random_state=seed)
    cvs.split()
    for fold in range(nfolds):
        train_path = cvs.train_paths[fold] + 'trajs.pkl'
        kf = KFoldCV(train_path, n_trajs=None, n_splits=n_splits, shuffle=False, random_state=seed)
        kf.split()

        print('-'*20, 'training agent', '-'*20)
        # agent
        config['persistent_directory'] = kf.agent_path
        config['checkpoint_path'] = kf.ckpt_path
        agent = KLAgent(num_actions=num_actions, config=config)
        agent.learn()

        print('-'*20, 'training agents', '-'*20)
        agent_1, ..., agent_K
        for idx in range(kf.n_splits):
            config_idx = copy.deepcopy(config)
            config_idx['persistent_directory'] = kf.agent_paths[idx]
            config_idx['checkpoint_path'] = kf.ckpt_paths[idx]
            agent_idx = KLAgent(num_actions=num_actions, config=config_idx)
            agent_idx.learn()

        # fitted q evaluation
        test_path = cvs.test_paths[fold] + 'trajs.pkl'
        with open(test_path, 'rb') as f:
            trajs = pickle.load(f)

        print('-'*20, 'behavior cloning', '-'*20)
        behavior cloning
        bc = BehaviorCloning(num_actions=num_actions)
        states  = np.array([transition[0] for traj in kf.trajs for transition in traj])
        actions = np.array([transition[1] for traj in kf.trajs for transition in traj])
        bc.train(states, actions)
        
        for ckpt in ckpts:
            print('-'*20, 'ckpt: ', ckpt, '-'*20)
            agent = KLAgent(num_actions=num_actions, config=config)
            agent.load(kf.ckpt_path + 'offline_kl_{}.ckpt'.format(ckpt))
        

            agents = []
            for idx in range(kf.n_splits):
                config_idx = copy.deepcopy(config)
                config_idx['persistent_directory'] = kf.agent_paths[idx]
                config_idx['checkpoint_path'] = kf.ckpt_paths[idx]
                agent_idx = KLAgent(num_actions=num_actions, config=config_idx)
                agent_idx.load(kf.ckpt_paths[idx] + 'offline_kl_{}.ckpt'.format(ckpt))
                agents.append(agent_idx)
            states, qvalues, qtildes = kf.update_q(agents, bc)

            print('-'*20, 'adv learner', '-'*20)
#             advs1 = qvalues - qvalues.mean(axis=1, keepdims=True)
#             agent1 = AdvantageLearner(num_actions=num_actions)
#             agent1._train(states, advs1)
            
            advs2 = qtildes - qtildes.mean(axis=1, keepdims=True)
            agent2 = AdvantageLearner(num_actions=num_actions)
            agent2._train(states, advs2)

            print('-'*20, 'fqe on dqn & peal', '-'*20)
            fqe_dqn = FQE(agent.greedy_actions, num_actions=num_actions, hiddens=[64, 64], activation='tanh', max_iter=100, eps=0.0015)
#             if fqe_dqn_weights_init != []:
#                 try:
#                     fqe_dqn.model.set_weights(fqe_dqn_weights_init)
#                 except:
#                     print('You called `set_weights(weights)` on layer "mlp_network" with a weight list of length 6, but the layer was expecting 0 weights.')
            fqe_dqn.train(trajs)
#             fqe_dqn_weights_init = fqe_dqn.model.get_weights()
#             fqe_dml = FQE(agent1.greedy_actions, num_actions=num_actions)
#             fqe_dml.train(trajs)
            fqe_peal = FQE(agent2.greedy_actions, num_actions=num_actions, hiddens=[64, 64], activation='tanh', max_iter=100, eps=0.0015)
#             if fqe_peal_weights_init != []:
#                 try:
#                     fqe_peal.model.set_weights(fqe_peal_weights_init)
#                 except:
#                     print('You called `set_weights(weights)` on layer "mlp_network" with a weight list of length 6, but the layer was expecting 0 weights.')
            fqe_peal.train(trajs)
#             fqe_peal_weights_init = fqe_peal.model.get_weights()

            rets.loc[(fold, ckpt), 'dqn'] = fqe_dqn.values
#             rets.loc[(fold, ckpt), 'dml'] = fqe_dml.values
            rets.loc[(fold, ckpt), 'peal'] = fqe_peal.values
            
    return rets

# %%
save_path = './data/mh/discrete_bear/'

pool = mp.Pool(5)
rets = pool.map(one_step, range(5))
pool.close()
with open(save_path + 'rets_discrete_bear_mh.pkl', 'wb') as f:
    pickle.dump(rets, f)
# Out:
# ---------------------------------------- start start  --------------------
# --------------------
# -------------------- training agent --------------------
# -------------------- training agent --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_1000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_1000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_2000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_2000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_3000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_3000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_4000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_4000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_5000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_5000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_6000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_6000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_7000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_7000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_8000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_8000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_9000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_9000.ckpt
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/ckpt/offline_kl_10000.ckpt
# -------------------- ckpt:  1000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/ckpt/offline_kl_10000.ckpt
# -------------------- ckpt:  1000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  0 target diff:  0.9185591586077734 values:  -47.871758 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  1 target diff:  0.00810970316595808 values:  -47.863556 -----
#
# -----iteration:  0 target diff:  0.9124311752444569 values:  -50.488987 -----
#
# -----iteration:  2 target diff:  0.004726607171491447 values:  -47.81002 -----
#
# -----iteration:  1 target diff:  0.007781666289529357 values:  -50.549873 -----
#
# -----iteration:  3 target diff:  0.002999305311719862 values:  -47.819767 -----
#
# -----iteration:  4 target diff:  0.003008843302265205 values:  -47.81705 -----
#
# -----iteration:  2 target diff:  0.004876904722714695 values:  -50.55743 -----
#
# -----iteration:  5 target diff:  0.0022795758878708457 values:  -47.787132 -----
#
# -----iteration:  3 target diff:  0.004687343760519431 values:  -50.477715 -----
#
# -----iteration:  6 target diff:  0.0024967112005215343 values:  -47.73028 -----
#
# -----iteration:  7 target diff:  0.002215011475367237 values:  -47.70718 -----
#
# -----iteration:  4 target diff:  0.003302978740479248 values:  -50.43743 -----
#
# -----iteration:  8 target diff:  0.002356295553867007 values:  -47.611202 -----
#
# -----iteration:  5 target diff:  0.002764009628083866 values:  -50.438442 -----
#
# -----iteration:  9 target diff:  0.002365631908064387 values:  -47.540894 -----
#
# -----iteration:  6 target diff:  0.002525308309705537 values:  -50.444958 -----
#
# -----iteration:  10 target diff:  0.001876015984668515 values:  -47.48791 -----
#
# -----iteration:  7 target diff:  0.0021158631928857256 values:  -50.51059 -----
#
# -----iteration:  8 target diff:  0.0031947614667987385 values:  -50.56704 -----
#
# -----iteration:  11 target diff:  0.002507583204411929 values:  -47.440823 -----
#
# -----iteration:  9 target diff:  0.0026418290757606396 values:  -50.522087 -----
#
# -----iteration:  12 target diff:  0.001802741465871187 values:  -47.437134 -----
#
# -----iteration:  10 target diff:  0.0025550894101472685 values:  -50.519836 -----
#
# -----iteration:  13 target diff:  0.002031155454696255 values:  -47.357204 -----
#
# -----iteration:  11 target diff:  0.0026421340535555398 values:  -50.574577 -----
#
# -----iteration:  14 target diff:  0.00237913417286164 values: -----iteration:  12  -47.323833target diff:   0.0024047486822785465 values:  -50.506 ----------
#
#
#
# -----iteration:  15 target diff:  -----iteration: 0.00185055371619405  13values:   target diff:  -47.2916260.002129877739358514  values:  ------50.53375 -----
#
#
#
# -----iteration:  14 target diff:  0.0020221150883651695 values:  -50.569405 -----
#
# -----iteration:  16 target diff:  0.0018179116405687289 values:  -47.252132 -----
#
# -----iteration:  15 target diff:  0.002132174040165322 values:  -50.568413 -----
#
# -----iteration:  17 target diff:  0.0020799193891129467 values:  -47.0975 -----
#
# -----iteration:  16 target diff:  0.0017744345190362166 values:  -50.624397 -----
#
# -----iteration:  18 target diff:  0.0028659918534593687 values:  -47.070637 -----
#
# -----iteration:  17 target diff:  0.002473774780836156 values:  -50.76743 -----
#
# -----iteration:  18 target diff:  0.002381291274735028 values:  -50.633186 -----
#
# -----iteration:  19 target diff:  0.0019545880599568764 values:  -46.980015 -----
#
# -----iteration:  19 target diff:  0.0016388351494343654 values:  -50.543846 -----
#
# -----iteration:  20 target diff:  0.0017199108641820866 values:  -46.85111 -----
#
# -----iteration:  21 target diff:  0.0028658913268666945 values:  -46.880825 -----
#
# -----iteration:  20 target diff:  0.0020183084215962114 values:  -50.56748 -----
#
# -----iteration:  21 target diff:  0.003128996755196969 values:  -50.46512 -----
#
# -----iteration:  22 target diff:  0.002209910618006017 values:  -46.81136 -----
#
# -----iteration:  22 target diff:  0.002760529840939862 values:  -50.51114 -----
#
# -----iteration:  23 target diff:  0.0022407341036428507 values:  -50.431858 -----
#
# -----iteration:  23 target diff:  0.0026029748779259256 values:  -46.746647 -----
#
# -----iteration:  24 target diff:  0.0018987519555402625 values:  -50.3216 -----
#
# -----iteration:  -----iteration: 24  25target diff:   target diff: 0.0035300044055226144 0.0018870159590317567 values:   -46.74403 -----values:  -50.3455
# -----
#
#
# -----iteration:  25 target diff:  0.003269866539872554 values:  -46.68678 -----
#
# -----iteration:  26 target diff:  0.002136315739285726 values:  -50.331566 -----
#
# -----iteration:  27 target diff:  0.002273349831493213 values:  -50.286186 -----
#
# -----iteration:  26 target diff:  0.002922361604714165 values:  -46.55063 -----
#
# -----iteration:  28 target diff:  0.0023210139626174734 values:  -50.208126 -----
#
# -----iteration:  29 target diff:  0.002089895996147577 values:  -50.08384 -----
#
# -----iteration:  27 target diff:  0.003712189565077549 values:  -46.485424 -----
#
# -----iteration:  30 target diff:  0.0027900842242191575 values:  -49.991108 -----
#
# -----iteration:  28 target diff:  0.003371702862320794 values:  -46.388332 -----
#
# -----iteration:  31 target diff:  0.0031287892801485037 values:  -49.86858 -----
#
# -----iteration:  32 target diff:  0.002354759575659987 values:  -49.91985 ----------iteration:  29
# target diff:
#  0.004396442411922754 values:  -46.274162 -----
#
# -----iteration:  33 target diff:  0.002264090048133254 values:  -49.912773 -----
#
# -----iteration:  34 target diff:  0.001993614541879289 values:  -49.870354 -----
#
# -----iteration:  30 target diff:  0.00407402453507642 values:  -46.151253 -----
#
# -----iteration:  35 target diff:  0.0021107699037237874 values:  -49.717068 -----
#
# -----iteration:  31 target diff:  0.005240520675086943 values:  -46.02753 -----
#
# -----iteration:  36 target diff:  0.0020321487133405343 values:  -49.7348 -----
#
# -----iteration:  32 target diff:  0.0050175086280405175 values:  -45.96588 -----
#
# -----iteration:  37 target diff:  0.0025801344673342897 values:  -49.732487 -----
#
# -----iteration:  33 target diff:  0.0038299317694953303 values:  -45.973164 -----
#
# -----iteration:  38 target diff:  0.0021863389287679227 values:  -49.65755 -----
#
# -----iteration:  39 target diff:  0.0019347255756890877 values:  -----iteration: -49.57079  34-----  target diff:
#
# 0.0034721989804372723 values:  -45.789055 -----
#
# -----iteration:  40 target diff:  0.001865357572321901 values:  -49.485233 -----
#
# -----iteration:  35 target diff:  0.005239476477411253 values:  -45.72367 -----
#
# -----iteration:  41 target diff:  0.0023843859964060537 values:  -49.364197 -----
#
# -----iteration:  36 target diff:  0.0036562723597454256 values:  -45.767883 -----
#
# -----iteration:  42 target diff:  0.002449337021430543 values:  -49.341312 -----
#
# -----iteration:  37 target diff:  0.00322507632535598 values:  -45.64741 -----
#
# -----iteration:  43 target diff:  0.0022436218267322915 values:  -49.201145 -----
#
# -----iteration:  44 target diff:  0.002887060956536098 values:  -49.077812 -----
#
# -----iteration:  38 target diff:  0.00490058666645812 values:  -45.477974 -----
#
# -----iteration:  45 target diff:  0.002610226294367664 values:  -48.973053 -----
#
# -----iteration:  39 target diff:  0.005632275471223443 values:  -45.340656 -----
#
# -----iteration:  46 target diff:  0.002617433029887052 values:  -48.846516 -----
#
# -----iteration:  40 target diff:  0.0037718369576926866 values:  -45.164577 -----
#
# -----iteration:  47 target diff:  0.002499066063688737 values:  -48.73257 -----
#
# -----iteration:  48 target diff:  0.0024058721376167226 values:  -48.576904 -----
#
# -----iteration:  41 target diff:  0.003582386482489271 values:  -44.869213 ----- -----iteration:
#
# 49 target diff:  0.002592868095969193 values:  -48.4343 -----
#
# -----iteration:  42 target diff:  0.00627762002701272 values:  -44.74381 -----
#
# -----iteration:  50 target diff:  0.0027326606886277356 values:  -48.3671 -----
#
# -----iteration:  51 target diff:  0.0022430819880988047 values:  -48.244896 -----
#
# -----iteration:  43 target diff:  0.004039870887369911 values:  -44.42392 -----
#
# -----iteration:  52 target diff:  0.0025841488862634915 values:  -48.265636 -----
#
# -----iteration:  44 target diff:  0.007087785165052708 values:  -44.127476 -----
#
# -----iteration:  53 target diff:  0.002629934167568253 values:  -48.21221 -----
#
# -----iteration:  45 target diff:  0.007092733562391907-----iteration:   values: 54  -43.850067target diff:   -----0.003364762317785055 values:
# -48.17239
#  -----
#
# -----iteration:  46 target diff:  0.006854613196106517 values:  -43.576363 -----
#
# -----iteration:  55 target diff:  0.0023152970041679186 values:  -48.031914 -----
#
# -----iteration:  56 target diff:  0.002700721276977302 values:  -47.89503 -----
#
# -----iteration:  47 target diff:  0.005398149662906134 values:  -43.31183 -----
# -----iteration:  57 target diff:  0.0026299078791195093 values:  -47.77637 -----
#
# -----iteration:  48 target diff:  0.007521828453694091 values:  -43.071636 -----
#
# -----iteration:  58 target diff:  0.0028622734580266793 values:  -47.676807 -----
#
# -----iteration:  49 target diff:  0.006106318320707184 values:  -42.812054 -----
#
# -----iteration:  59 target diff:  0.002697293718952061 values:  -47.58132 -----
#
# -----iteration:  50 target diff:  0.005841113699873013 values:  -42.553936 -----
#
# -----iteration:  60 target diff:  0.002327099654219986 values:  -47.47473 -----
#
# -----iteration:  51 target diff:  0.005452299215780968 values:  -42.29826 -----
#
# -----iteration:  61 target diff:  0.002529393635191214 values:  -47.36484 -----
#
# -----iteration:  52 target diff:  0.005232985840932566 values:  -42.08378 -----
#
# -----iteration:  62 target diff:  0.0026543744545211375 values:  -47.254005 -----
#
# -----iteration:  53 target diff:  0.005049820982844556 values:  -41.867466 -----
#
# -----iteration:  63 target diff:  0.0027540747360771988 values:  -47.141407 -----
#
# -----iteration:  54 target diff:  0.005174014816053173 values:  -41.671043 -----
#
# -----iteration:  64 target diff:  0.002716318477582571 values:  -47.015747 -----
#
# -----iteration:  55 target diff:  0.004730460515324619 values:  -41.49062 -----
#
# -----iteration:  65 target diff:  0.002858665680625365 values:  -46.921413 -----
#
# -----iteration:  56 target diff:  0.004400593641196202 values:  -41.327293 -----
#
# -----iteration:  66 target diff:  0.0032551566018455998 values:  -46.804607 -----
#
# -----iteration:  57 target diff:  0.004063269612474013 values:  -41.167763 -----
#
# -----iteration:  67 -----iteration:  target diff: 58 0.0032023790167181997  target diff: values:   -46.71426 0.004181272350644283-----
# values:
#  -41.0033 -----
#
# -----iteration:  68 target diff:  0.002943467900839888 values:  -46.670597 -----
#
# -----iteration:  59 target diff:  0.004126440862778407 values:  -40.82748 -----
#
# -----iteration:  69 target diff:  -----iteration: 0.002944106997117956  60values:   target diff: -46.517376  0.003920069762202008-----  values:
# -40.653088
# -----
#
# -----iteration: -----iteration:   7061 target diff:  target diff:   0.0031364373898735870.0038249191371940404  values:  values: -46.474182  -40.457367-----
# -----
#
#
# -----iteration:  71 target diff:  0.0027812042625860317 values:  -46.342815 -----iteration: -----
# 62
#  target diff:  0.003868517320475273 values:  -40.263805 -----
#
# -----iteration:  72 target diff:  0.003238526145864241 values:  -46.298286 -----
#
# -----iteration:  63 target diff:  0.0038242831898436425 values:  -40.002903 -----
#
# -----iteration:  73 target diff:  0.002972470411061682 values:  -46.215908 -----
#
# -----iteration:  74 target diff:  0.0028856592964629905 values:  -46.151436 -----
#
# -----iteration:  64 target diff:  0.006390146406075934 values:  -39.79787 -----
#
# -----iteration:  75 target diff:  0.0028505424994739134 -----iteration: values:   65-46.108574  target diff: -----
# 0.0038707910445583624 values:
#  -39.67104 -----
#
# -----iteration:  76 target diff:  0.002781500704807239 values:  -46.068645 -----
#
# -----iteration:  66 target diff:  0.0038933662791706286 values:  -39.46934 -----
#
# -----iteration:  77 target diff:  0.0028563519504120004 values:  -45.998775 -----
#
# -----iteration:  67 target diff:  0.004897036579871691 values:  -39.30988 -----
#
# -----iteration:  78 target diff:  0.0035920926864702937 values:  -45.89081 -----
#
# -----iteration:  68 target diff:  0.0039744541654753674 values:  -39.10369 -----
#
# -----iteration:  79 target diff:  0.003156797234487783 values:  -45.752014 -----
#
# -----iteration:  69 target diff:  0.004060441856320293 values:  -38.93845 -----
#
# -----iteration:  80 target diff:  0.0030552994712747523 values:  -45.720875 -----
#
# -----iteration:  70 target diff:  0.003332451371392542 values:  -38.801556 -----
#
# -----iteration:  81 target diff:  0.002888875367609533 values:  -45.657166 -----
#
# -----iteration:  71 target diff:  0.0032100219795274647 values:  -38.700863 -----
#
# -----iteration:  82 target diff:  0.003147611251940539 values:  -45.63632 -----
#
# -----iteration:  72 target diff:  0.0031365108013481644 values:  -38.558216 -----
#
# -----iteration:  83 target diff:  0.002873083600125194 values:  -45.5534 -----
#
# -----iteration:  73 target diff:  0.002940520393440763 values:  -38.494804 -----
#
# -----iteration:  84 target diff:  0.00303451464576434 values:  -45.4477 -----
#
# -----iteration:  74 target diff:  0.002745793678034455 values:  -38.39245 -----
#
# -----iteration:  85 target diff:  0.0032944594922270096 values:  -45.39706 -----
#
# -----iteration:  -----iteration: 86  75target diff:   0.0027118215211217904target diff:   values: 0.002933806590687935  values: -45.327984  ------38.25183
#
# -----
#
# -----iteration:  87 target diff:  0.002906043286422459 values:  -45.225395 -----
#
# -----iteration:  76 target diff:  0.003437014629143839 values:  -38.170948 -----
#
# -----iteration:  88 target diff:  0.003156561726378896 values:  -45.12154 -----
#
# -----iteration:  77 target diff:  0.0027855471801129803 values:  -38.061314 -----
#
# -----iteration:  89 target diff:  0.002596779623890202 values:  -45.011963 -----
#
# -----iteration:  78 target diff:  0.003216631516919776 values:  -37.964756 -----
#
# -----iteration:  90 target diff:  0.0031147996557582785 values:  -44.96713 -----
#
# -----iteration:  79 target diff:  0.002714226648221111 values:  -38.012814 -----
#
# -----iteration:  91 target diff:  0.0028702999042431857 values:  -44.81706 -----
#
# -----iteration:  80 target diff:  0.002647450800508908 values:  -37.886806 -----
#
# -----iteration:  92 target diff:  0.0027976733981184766 values:  -44.699627 -----
#
# -----iteration:  81 target diff:  0.0025753303656982475 values:  -37.79472 -----
#
# -----iteration:  93 target diff:  0.00263195867106334 values:  -44.631863 -----
#
# -----iteration:  94 target diff:  0.0027328571391490642 values:  -44.57438 -----
#
# -----iteration:  82 target diff:  0.002945131561256083 values:  -37.639305 -----
#
# -----iteration:  95 target diff:  0.00282315078037068 -----iteration: values:   -44.58194483  target diff: -----  0.002743782230522897
#
# values:  -37.547203 -----
#
# -----iteration:  96 target diff:  0.0029036723542640104 values:  -44.479595 -----
#
# -----iteration:  84 target diff:  0.0023455497989953483 values:  -37.55354 -----
#
# -----iteration:  97 target diff:  0.002783561068740273 values:  -44.375114 -----
#
# -----iteration:  85 target diff:  0.00201976562138449 values:  -37.468193 -----
#
# -----iteration: -----iteration:   9886  target diff: target diff:   0.00205141900455296880.0029542062436664373  values:  values: -37.350952  ------44.277588
# -----
#
#
# -----iteration:  87 target diff:  0.001879356576304952 values:  -----iteration: -37.246304 -----
# 99
#  target diff:  0.0026881723692099694 values:  -44.223278 -----
#
# -------------------- ckpt:  2000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# -----iteration:  88 target diff:  0.002227605133660721 values:  -37.198334 -----
#
# -----iteration:  89 target diff:  0.0019092708496655606 values:  -37.078075 -----
#
# -----iteration:  90 target diff:  0.0020028775635813315 values:  -37.09884 -----
#
# -----iteration:  91 target diff:  0.001886827491215337 values:  -37.04826 -----
#
# -----iteration:  92 target diff:  0.0018329114639265873 values:  -36.99399 -----
#
# -----iteration:  93 target diff:  0.001935796388803709 values:  -36.958775 -----
#
# -----iteration:  94 target diff:  0.001978730458909026 values:  -36.97304 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  95 target diff:  0.0017281887191610567 values:  -36.987617 -----
#
# -----iteration:  96 target diff:  0.0017221018243600648 values:  -36.96454 -----
#
# -----iteration:  0 target diff:  0.9116593669906531 values:  -51.532978 -----
#
# -----iteration:  97 target diff:  0.0017743563826399839 values:  -37.05933 -----
#
# -----iteration:  1 target diff:  0.003012141820224872 values:  -51.512066 -----
#
# -----iteration:  98 target diff:  0.0018718830346172797 values:  -37.07537 -----
#
# -----iteration:  2 target diff:  0.0027394584384754696 values:  -51.507473 -----
#
# -----iteration:  99 target diff:  0.001966919646433891 values:  -37.13712 -----
#
# -------------------- ckpt:  2000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# -----iteration:  3 target diff:  0.002739511555767413 values:  -51.50867 -----
#
# -----iteration:  4 target diff:  0.00281448574389292 values:  -51.49952 -----
#
# -----iteration:  5 target diff:  0.0022677281147054085 values:  -51.545757 -----
#
# -----iteration:  6 target diff:  0.0021064672411211785 values:  -51.43286 -----
#
# -----iteration:  7 target diff:  0.002144369674241428 values:  -51.36255 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  8 target diff:  0.001551234316090813 values:  -51.259647 -----
#
# -----iteration:  9 target diff:  0.002918907267800109 values:  -51.320034 -----
#
# -----iteration:  0 target diff:  0.9177451747788374 values:  -48.732708 -----
#
# -----iteration:  10 target diff:  0.0019360204862163455 values:  -51.333164 -----
#
# -----iteration:  11 target diff:  0.0014412354708193034 values:  -51.32007 -----
#
# -------------------- ckpt:  3000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# -----iteration:  1 target diff:  0.005536727113004523 values:  -48.712776 -----
#
# -----iteration:  2 target diff:  0.002154581395541345 values:  -48.71174 -----
#
# -----iteration:  3 target diff:  0.002598654357163485 values:  -48.775723 -----
#
# -----iteration:  4 target diff:  0.0027370580237098727 values:  -48.821953 -----
#
# -----iteration:  5 target diff:  0.002225056342851317 values:  -48.789402 -----
#
# -----iteration:  6 target diff:  0.001733942808239077 values:  -48.7583 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# -----iteration:  7 target diff:  0.0019707782325431166 values:  -48.768738 -----
#
# -----iteration:  8 target diff:  0.00198031869710119 values:  -48.68766 -----
#
# -----iteration:  9 target diff:  0.0021690658687595547 values:  -48.671364 -----
#
# -----iteration:  0 target diff:  0.9111728371249166 values:  -51.2384 -----
#
# -----iteration:  10 target diff:  0.0016389300083064998 values:  -48.752323 -----
#
# -----iteration:  1 target diff:  0.0029777286146075808 values:  -51.177586 -----
#
# -----iteration:  11 target diff:  0.0024262028962459456 values:  -48.724262 -----
#
# -----iteration:  2 target diff:  0.0023354709511557276 values:  -51.21978 -----
#
# -----iteration:  12 target diff:  0.0013476507008457362 values:  -48.625618 -----
#
# -------------------- ckpt:  3000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# -----iteration: WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 3 target diff:  0.0025921143134605843 values:  -51.235603 -----
#
# -----iteration:  4 target diff:  0.0021417428926189374 values:  -51.187965 -----
#
# -----iteration:  5 target diff:  0.002763723277939495 values:  -51.1683 -----
#
# -----iteration:  6 target diff:  0.0016108205718503084 values:  -51.11264 -----
#
# -----iteration:  7 target diff:  0.0017224414149269109 values:  -51.11436 -----
#
# -----iteration:  8 target diff:  0.0014645817191418498 values:  -51.142254 -----
#
# -------------------- ckpt:  4000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  0 target diff:  0.9180786533189474 values:  -48.650745 -----
#
# -----iteration:  1 target diff:  0.0038527340234363727 values:  -48.660454 -----
#
# -----iteration:  2 target diff:  0.0019025803538102336 values:  -48.61419 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  3 target diff:  0.0021500966486287616 values:  -48.67355 -----
#
# -----iteration:  0 target diff:  0.9124435187980252 values:  -49.783264 -----
#
# -----iteration:  4 target diff:  0.0023426850298889183 values:  -48.693516 -----
#
# -----iteration:  1 target diff:  0.003670551799232395 values:  -49.74371 -----
#
# -----iteration:  5 target diff:  0.0013399370830108283 values:  -48.69676 -----
#
# -----iteration:  --------------------2  ckpt: target diff:   4000 --------------------0.0021376057381398803
# values:  -49.687004 -----
#
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# -----iteration:  3 target diff:  0.002151528238331682 values:  -49.705547 -----
#
# -----iteration:  4 target diff:  0.002034918180716698 values:  -49.61507 -----
#
# -----iteration:  5 target diff:  0.0019299546549612406 values:  -49.7103 -----
#
# -----iteration:  6 target diff:  0.0021760738718746755 values:  -49.82456 -----
#
# -----iteration:  7 target diff:  0.0018736500253205297 values:  -49.84967 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  8 target diff:  0.0017696329706121952 values:  -49.90389 -----
#
# -----iteration:  0 target diff:  0.9201571577012285 values:  -48.36377 -----
#
# -----iteration:  9 target diff:  0.0018700652262354448 values:  -49.90414 -----
#
# -----iteration:  1 target diff:  0.0018974218064841592 values:  -48.3945 -----
#
# -----iteration:  2 target diff:  0.0020902008860031263 values:  -48.35926 -----
#
# -----iteration:  10 target diff:  0.001694256618899191 values:  -49.89414 -----
#
# -----iteration:  3 target diff:  0.001471296704085509 values:  -48.31827 -----
#
# -------------------- ckpt:  5000 --------------------
# -----iteration: Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold0/train/agent/trajs.pkl!
# 11 target diff: Refresh buffer every 1000000 sampling!
#  0.002039289407454483 values:  -49.950397 -----
#
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# -----iteration:  12 target diff:  0.0016732760947129495 values:  -49.868626 -----
#
# -----iteration:  13 target diff:  0.001796314779291945 values:  -49.972343 -----
#
# -----iteration:  14 target diff:  0.001869961454992852 values:  -50.03512 -----
#
# -----iteration:  15 target diff:  0.0025172115409251863 values:  -50.17585 -----
#
# -----iteration:  16 target diff:  0.00189527605942011 values:  -50.234688 -----
#
# -----iteration:  17 target diff:  0.002311963950905197 values:  -50.306576 -----
#
# -----iteration:  18 target diff:  0.0019130691974554154 values:  -50.3701 -----
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  19 target diff:  0.0018019237847746348 values:  -50.312344 -----
#
# -----iteration:  20 target diff:  0.002117446247610173 values:  -50.310173 -----
#
# -----iteration:  0 target diff:  0.9189113659155934 values:  -48.879665 -----
#
# -----iteration:  21 target diff:  0.004240293573961318 values:  -50.240112 -----
#
# -----iteration:  1 target diff:  0.0026607763170504685 values:  -48.936314 -----
#
# -----iteration:  22 target diff:  0.001604783593322799 values:  -50.146145 -----
#
# -----iteration:  2 target diff:  0.0018366375014102349 values:  -48.857555 -----
#
# -----iteration:  23 target diff:  0.0018686709869093863 values:  -50.114197 -----
#
# -----iteration:  3 target diff:  0.0015565529261591694 values:  -48.875572 -----
#
# -----iteration:  24 target diff:  0.001417415866219343 values:  -50.127804 -----
#
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# -----iteration:  0 target diff:  0.9121228320650705 values:  -48.826572 -----
#
# -----iteration:  1 target diff:  0.005002408382484267 values:  -48.79881 -----
#
# -----iteration:  2 target diff:  0.002544203957205581 values:  -48.84854 -----
#
# -----iteration:  3 target diff:  0.0024542618521534543 values:  -48.77303 -----
#
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold1/train/agent/ckpt/offline_kl_1000.ckpt
# -----iteration:  4 target diff:  0.002215864978414382 values:  -48.75647 -----
#
# -----iteration:  5 target diff:  0.001825061471531083 values:  -48.715385 -----
#
# -----iteration:  6 target diff:  0.0020716110066330987 values:  -48.62271 -----
#
# -----iteration:  7 target diff:  0.002412050935017079 values:  -48.629982 -----
#
# -----iteration:  8 target diff:  0.0016016761840012435 values:  -48.626453 -----
#
# -----iteration:  9 target diff:  0.00141344146325084 values:  -48.596245 -----
#
# -------------------- ckpt:  10000 --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold0/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# -------------------- fqe on dqn & sale --------------------
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).action_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).q_head.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).affine_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).imitation_layers.1.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# -----iteration:  0 target diff:  0.9120704562465765 values:  -51.504753 -----
#
# -----iteration:  1 target diff:  0.006324454502637083 values:  -51.541878 -----
#
# -----iteration:  2 target diff:  0.0027167334359829254 values:  -51.48101 -----
#
# -----iteration:  3 target diff:  0.0027901241557260234 values:  -51.45444 -----
#
# -----iteration:  4 target diff:  0.0033104565721850106 values:  -51.443733 -----
#
# -----iteration:  5 target diff:  0.0016999744508440647 values:  -51.37751 -----
#
# -----iteration:  6 target diff:  0.0018134561424615861 values:  -51.43711 -----
#
# -----iteration:  7 target diff:  0.0022618703098555046 values:  -51.359524 -----
#
# -----iteration:  8 target diff:  0.0022514333908860516 values:  -51.376926 -----
#
# -----iteration:  9 target diff:  0.0015988545847271402 values:  -51.402107 -----
#
# -----iteration:  10 target diff:  0.001584659969404036 values:  -51.543636 -----
#
# -----iteration:  11 target diff:  0.002389652355586579 values:  -51.586662 -----
#
# -----iteration:  12 target diff:  0.0018388897566336288 values:  -51.66618 -----
#
# -----iteration:  13 target diff:  0.002171798314165923 values:  -51.772236 -----
#
# -----iteration:  14 target diff:  0.0020156996197136217 values:  -51.863106 -----
#
# -----iteration:  15 target diff:  0.002152893535420172 values:  -51.868786 -----
#
# -----iteration:  16 target diff:  0.002455346709360862 values:  -51.97164 -----
#
# -----iteration:  17 target diff:  0.0026187424157801255 values:  -52.03091 -----
#
# -----iteration:  18 target diff:  0.0016881307381454518 values:  -52.037006 -----
#
# -----iteration:  19 target diff:  0.0016391591487087782 values:  -52.150475 -----
#
# -----iteration:  20 target diff:  0.0023987619463778616 values:  -52.140198 -----
#
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold1/train/agent/ckpt/offline_kl_2000.ckpt
# -----iteration:  21 target diff:  0.0015630165160429308 values:  -52.18174 -----
#
# -----iteration:  22 target diff:  0.001962785332963245 values:  -52.22384 -----
#
# -----iteration:  23 target diff:  0.0016912929850858003 values:  -52.315605 -----
#
# -----iteration:  24 target diff:  0.001974213141276412 values:  -52.320484 -----
#
# -----iteration:  25 target diff:  0.0018065308565142263 values:  -52.32719 -----
#
# -----iteration:  26 target diff:  0.002092870314109622 values:  -52.300423 -----
#
# -----iteration:  27 target diff:  0.002408702251588962 values:  -52.267906 -----
#
# -----iteration:  28 target diff:  0.002374862343349608 values:  -52.29189 -----
#
# -----iteration:  29 target diff:  0.0022241054845093737 values:  -52.288006 -----
#
# -----iteration:  30 target diff:  0.002847287802920872 values:  -52.189754 -----
#
# -----iteration:  31 target diff:  0.002082045264728523 values:  -51.964207 -----
#
# -----iteration:  32 target diff:  0.0025528321198436755 values:  -51.864758 -----
#
# -----iteration:  33 target diff:  0.0016757880535455405 values:  -51.76754 -----
#
# -----iteration:  34 target diff:  0.0017009952465212507 values:  -51.651997 -----
#
# -----iteration:  35 target diff:  0.002077185515583632 values:  -51.697044 -----
#
# -----iteration:  36 target diff:  0.0028393738951322947 values:  -51.56296 -----
#
# -----iteration:  37 target diff:  0.002008438559266625 values:  -51.439 -----
#
# -----iteration:  38 target diff:  0.001833159545875932 values:  -51.306892 -----
#
# -----iteration:  39 target diff:  0.002358696786976954 values:  -51.1556 -----
#
# -----iteration:  40 target diff:  0.002463566083374199 values:  -51.018517 -----
#
# -----iteration:  41 target diff:  0.0021485989942420214 values:  -50.87605 -----
#
# -----iteration:  42 target diff:  0.0018998133876514083 values:  -50.732674 -----
#
# -----iteration:  43 target diff:  0.0017510294922951327 values:  -50.601307 -----
#
# -----iteration:  44 target diff:  0.0017770008330733344 values:  -50.47278 -----
#
# -----iteration:  45 target diff:  0.0017039117807656323 values:  -50.354004 -----
#
# -----iteration:  46 target diff:  0.0015318706888400244 values:  -50.227886 -----
#
# -----iteration:  47 target diff:  0.0015488525639928892 values:  -50.174168 -----
#
# -----iteration:  48 target diff:  0.001992224772595918 values:  -50.110332 -----
#
# -----iteration:  49 target diff:  0.002174535899678255 values:  -50.047127 -----
#
# -----iteration:  50 target diff:  0.002231013804366534 values:  -49.972164 -----
#
# -----iteration:  51 target diff:  0.002272266255327612 values:  -49.897797 -----
#
# -----iteration:  52 target diff:  0.0023461319060580346 values:  -49.84696 -----
#
# -----iteration:  53 target diff:  0.0023245702588341986 values:  -49.792515 -----
#
# -----iteration:  54 target diff:  0.0024706790787437493 values:  -49.71812 -----
#
# -----iteration:  55 target diff:  0.0023681968195067692 values:  -49.673557 -----
#
# -----iteration:  56 target diff:  0.0022227738328240132 values:  -49.64414 -----
#
# -----iteration:  57 target diff:  0.0022590751092620774 values:  -49.5581 -----
#
# -----iteration:  58 target diff:  0.0020788572808066678 values:  -49.498005 -----
#
# -----iteration:  59 target diff:  0.0022796621452880737 values:  -49.390675 -----
#
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold1/train/agent/ckpt/offline_kl_3000.ckpt
# -----iteration:  60 target diff:  0.0016662369899303252 values:  -49.326782 -----
#
# -----iteration:  61 target diff:  0.002518710701060572 values:  -49.250874 -----
#
# -----iteration:  62 target diff:  0.0022861402463480473 values:  -49.207058 -----
#
# -----iteration:  63 target diff:  0.0021106386062376596 values:  -49.14152 -----
#
# -----iteration:  64 target diff:  0.002110696387658902 values:  -49.06588 -----
#
# -----iteration:  65 target diff:  0.0021910670180327442 values:  -48.994663 -----
#
# -----iteration:  66 target diff:  0.0027846458335355115 values:  -48.919834 -----
#
# -----iteration:  67 target diff:  0.0019447514369267443 values:  -48.856274 -----
#
# -----iteration:  68 target diff:  0.0019893824415469106 values:  -48.80962 -----
#
# -----iteration:  69 target diff:  0.0025318525333067853 values:  -48.718864 -----
#
# -----iteration:  70 target diff:  0.0024421563679762797 values:  -48.65412 -----
#
# -----iteration:  71 target diff:  0.0029383940824453288 values:  -48.539436 -----
#
# -----iteration:  72 target diff:  0.002832054689921519 values:  -48.45602 -----
#
# -----iteration:  73 target diff:  0.0025790668540403203 values:  -48.366264 -----
#
# -----iteration:  74 target diff:  0.0025472823064425186 values:  -48.27752 -----
#
# -----iteration:  75 target diff:  0.0025561812472302443 values:  -48.223843 -----
#
# -----iteration:  76 target diff:  0.0027376851117274174 values:  -48.1232 -----
#
# -----iteration:  77 target diff:  0.0024887072072448816 values:  -48.06558 -----
#
# -----iteration:  78 target diff:  0.0021983554514978243 values:  -47.99542 -----
#
# -----iteration:  79 target diff:  0.002555017558979898 values:  -47.905327 -----
#
# -----iteration:  80 target diff:  0.0029101787025779466 values:  -47.80788 -----
#
# -----iteration:  81 target diff:  0.00292032559724336 values:  -47.713432 -----
#
# -----iteration:  82 target diff:  0.002928359603358756 values:  -47.616333 -----
#
# -----iteration:  83 target diff:  0.0027008964498780757 values:  -47.533882 -----
#
# -----iteration:  84 target diff:  0.002889516625688274 values:  -47.47591 -----
#
# -----iteration:  85 target diff:  0.0023999100928446503 values:  -47.41985 -----
#
# -----iteration:  86 target diff:  0.002902076624346058 values:  -47.42539 -----
#
# -----iteration:  87 target diff:  0.002577526150726224 values:  -47.43465 -----
#
# -----iteration:  88 target diff:  0.002997500245932973 values:  -47.420483 -----
#
# -----iteration:  89 target diff:  0.0021207477517877554 values:  -47.373524 -----
#
# -----iteration:  90 target diff:  0.002774706115342667 values:  -47.310127 -----
#
# -----iteration:  91 target diff:  0.0029033944208464667 values:  -47.29998 -----
#
# -----iteration:  92 target diff:  0.0024526102888363702 values:  -47.28287 -----
#
# -----iteration:  93 target diff:  0.002891314084148328 values:  -47.270752 -----
#
# -----iteration:  94 target diff:  0.002212374969010567 values:  -47.259968 -----
#
# -----iteration:  95 target diff:  0.0026090038597737465 values:  -47.249664 -----
#
# -----iteration:  96 target diff:  0.002229831823513866 values:  -47.249825 -----
#
# -----iteration:  97 target diff:  0.0025870398268990472 values:  -47.253242 -----
#
# -----iteration:  98 target diff:  0.0023259176432817177 values:  -47.216763 -----
#
# -----iteration:  99 target diff:  0.0022404699711207217 values:  -47.25013 -----
#
# -------------------- training agent --------------------
# Loaded trajectories from load path: /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/774252441/fold1/train/agent/trajs.pkl!
# Refresh buffer every 1000000 sampling!
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer kl_network is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# saving model weights at /home/jupyt/leyuan/SUPRL/data/mh/kl/tmp/91571465/fold1/train/agent/ckpt/offline_kl_4000.ckpt
